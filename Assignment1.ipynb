# %% [markdown]
# 1.Reading a dataset to python environment

# %%
import pandas as pd

# %%
data=pd.read_excel('iris.xls')

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2.Display the columns in the dataset

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3.Calculate mean of each columns in the dataset

# %%
data.mean()
# Out:
# <ipython-input-9-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# 4.Checking for the null values present in the dataset

# %%
data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# 5.Visualisations using the dataset

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# #COUNTPLOT

# %%
sns.countplot(x='Classification', data=data)
plt.title('Countplot of Iris Species')
plt.xlabel('Classification')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #BOX PLOT

# %%
plt.title('Boxplot of Iris Features by Classification')
sns.boxplot(x='Classification', y='SW', data=data)
plt.show()

# %% [markdown]
# SCATTER PLOT

# %%
sns.scatterplot(x='SL', y='SW', hue='Classification', data=data, edgecolor='b', s=150)
plt.title('Scatter Plot of SL vs SW by Classification')
plt.xlabel('SL')
plt.ylabel('SW')
plt.show()
